# %% [markdown]
# # Interpolación cuadrática.
#
# **Objetivo general.**
#
# Revisar e implementar una interpolación cuadrática y aplicarlas a datos reales.
#
# **Trabajo realizado con el apoyo del Programa UNAM-DGAPA-PAPIME, proyectos PE101019, PE101922 y PE106025.**
#
# [![License: CC BY-SA 4.0](https://img.shields.io/badge/License-CC_BY--SA_4.0-lightgrey.svg)](https://creativecommons.org/licenses/by-sa/4.0/)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import macti.vis as mvis

# %% [markdown]
# La interpolación lineal descrita en la notebook [01_interpolacion_lineal.ipynb](01_interpolacion_lineal.ipynb) no parece ser muy efectiva, a menos que se tenga mucha información.
#
# Una forma de mejorar es mediante el uso de polinomios de más alto orden. Por ejemplo un polinomio cuadrático:
#
# $$
# S(x) = a + b x + c x^2
# $$
#
#
# <div class="alert alert-success">
#
# ## Ejemplo 1.
# Dados el siguiente conjunto de datos:
#
# |$x$  | $f(x)$ |
# |:-:|:-:|
# |$2$|$45$|
# |$3$|$23$|
# |$4$|$67$|
#
# Realizar una interpolación en el punto $x = 2.5$ usando una función cuadrática.
#
# </div>

# %% [markdown]
# ### Paso 1. Graficación de los datos.

# %%
x0, x1, x2 = 2, 3, 4
f0, f1, f2 = 45, 23, 67

# Graficación de los datos 
plt.scatter([x0, x1, x2], [f0, f1, f2], 
            ec='dimgray', fc='darkgray', alpha=0.95, zorder=5, 
            label='Datos originales')
# Líneas que unen a los datos
plt.plot([x0, x1, x2], [f0, f1, f2], '--', color='darkgray', lw = 1.0)

plt.ylim(0,70)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Paso 2. Construcción de una función cuadrática
#
# Si evaluamos la función cuadrática en cada uno de los tres puntos obtenemos:
#
# $$
# \begin{eqnarray}
# S(x_0) & = & a + b x_0 + c x_0^2 \\
# S(x_1) & = & a + b x_1 + c x_1^2\\
# S(x_2) & = & a + b x_2 + c x_2^2
# \end{eqnarray}
# $$
#
# Tenemos entonces un sistema de ecuaciones que debemos resolver para encontrar los coeficientes $a$, $b$ y $c$:
#
# $$
# \left[
# \begin{array}{ccc}
# 1 & x_0 & x_0^2 \\
# 1 & x_1 & x_1^2 \\
# 1 & x_2 & x_2^2
# \end{array}
# \right]
# \left[
# \begin{array}{c}
# a \\ b \\ c
# \end{array}
# \right]
# =
# \left[
# \begin{array}{c}
# f(x_0) \\ f(x_1) \\ f(x_2)
# \end{array}
# \right]
# $$
#
# La matriz del lado izquierdo suele conocerse como [Vandermonde matrix](https://en.wikipedia.org/wiki/Vandermonde_matrix).
#
# De acuerdo con los datos definidos antes (`x0`, `f0`), (`x1`, `f1`) y (`x2`, `f2`) podemos
# definir la matriz y el lado derecho (RHS) del sistema lineal como sigue:

# %%
A = np.array([[1, x0, x0**2],
              [1, x1, x1**2],
              [1, x2, x2**2]])

RHS = np.array([f0,f1,f2])

print(f"Matriz: \n{A}")
print(f"RHS: \n{RHS}")
# Out:
# Matriz:
# [[ 1  2  4]
#  [ 1  3  9]
#  [ 1  4 16]]
# RHS:
# [45 23 67]

# %% [markdown]
# Para resolver este sistema y encontrar los coeficientes ($a, b, c$) del polinomio cuadrático usamos la función [`np.linalg.solve()`](https://numpy.org/doc/2.2/reference/generated/numpy.linalg.solve.html):

# %%
sol = np.linalg.solve(A, RHS)
print(f"Coeficientes: \n{sol}")
# Out:
# Coeficientes:
# [ 287. -187.   33.]

# %% [markdown]
# Si multiplicamos la matriz `A` por esta solución, deberíamos recuperar el lado derecho del sistema (RHS) es decir el arreglo `[42 23 67]`; esto lo podemos hacer como sigue:

# %%
np.dot(A, sol)
# Out:
# array([45., 23., 67.])

# %% [markdown]
# Observamos que si obtenemos el RHS por lo que confiamos en el resultado.
#
# Ahora implementamos la función cuadrática:

# %%
S_q = lambda x, a, b, c: a  + b * x + c * x**2

# %% [markdown]
# Evaluamos la función cuadrática en el punto $x = 2.5$:

# %%
# Renombramos los coeficientes para facilidad de uso
a, b, c = sol[0], sol[1], sol[2] 

# Realizamos la interpolación cuadrática
x = 2.5
y = S_q(x, a, b, c)
print(f"Resultado de la interpolación cuadrática: {y}")
# Out:
# Resultado de la interpolación cuadrática: 25.75

# %% [markdown]
# ### Paso 3. Graficamos el resultado:

# %%
# Graficación de los datos 
plt.scatter([x0, x1, x2], [f0, f1, f2], 
            ec='dimgray', fc='darkgray', alpha=0.95, zorder=5, 
            label='Datos originales')
# Líneas que unen a los datos
plt.plot([x0, x1, x2], [f0, f1, f2], '--', color='darkgray', lw = 1.0)

# Datos interpolados
plt.scatter(x, y, ec='brown', fc='tomato', zorder=5, 
            label='Punto interpolado') 

plt.ylim(0,70)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Sería bueno graficar la función cuadrática en vez de las líneas rectas:

# %%
# Primero construimos la función cuadrática con 50 puntos
xq = np.linspace(2,4,50)
yq = S_q(xq, a, b, c)

# %%
# Graficación de los datos 
plt.scatter([x0, x1, x2], [f0, f1, f2], 
            ec='dimgray', fc='darkgray', alpha=0.95, zorder=5, 
            label='Datos originales')
# Curva cuadrática que une a los datos
plt.plot(xq, yq, '--', color='darkgray', lw = 1.0)

# Datos interpolados
plt.scatter(x, y, ec='brown', fc='tomato', zorder=5, 
            label='Punto interpolado') 

plt.ylim(0,70)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
# ## Ejemplo 2.
#
# Aplicar la interpolación cuadrática a un punto del los datos del artículo de *Canet et al. (2015)*.
#
# </div>

# %% [markdown]
# ### Paso 1. Graficamos los datos.
#
# Retomando el ejemplo del artículo:
#
# <blockquote cite="https://doi.org/10.1016/j.jvolgeores.2015.09.019">
#     Canet, Carles <i>et al</i>. (<b>2015</b>). Thermal history of the Acoculco geothermal system, eastern Mexico: Insights from numerical modeling and radiocarbon dating. <i>Journal of Volcanology and Geothermal Research</i>. <b>305<b>. https://doi.org/10.1016/j.jvolgeores.2015.09.019
# </blockquote>
#
# Leemos el conjunto de datos y los graficamos:

# %%
datos = pd.read_csv('T_inicial.csv')
datos
# Out:
#     Depth  Temp
# 0       0    15
# 1     100   113
# 2     200   145
# 3     400   178
# 4     710   155
# 5     803   201
# 6    1100   215
# 7    1200   282
# 8    1400   223
# 9    1500   226
# 10   1600   252
# 11   1700   284
# 12   1800   310
# 13   2000   350
# 14   2500   450
# 15   3000   550
# 16   3500   650
# 17   4000   750

# %%
# Graficación de los datos 
plt.scatter(datos.Temp, datos.Depth, label='Datos',
            ec='dimgrey', fc='darkgrey', alpha=0.95, zorder=5, )
# Líneas que unen a los datos
plt.plot(datos.Temp, datos.Depth, 
         '--', color='darkgrey', lw = 1.0)

ax = plt.gca() # Obtenemos los ejes de la figura
ax.invert_yaxis() # Invertimos el eje y

# Ponemos los ticks y labels en arriba
ax.tick_params(axis='x', top=True, labeltop=True, bottom=False, labelbottom=False)

# Modificamos algunas líneas del marco.
ax.spines['top'].set_visible(True)
ax.spines['bottom'].set_visible(False)

plt.title('Temperatura [$^o$C]', loc="center", y=1.10)
plt.ylabel('Profundidad [km]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Paso 2. Construcción de la función cuadrática.
#
# Necesitamos seleccionar tres pares del conjunto de datos, por ejemplo:

# %%
datos.loc[6:8]
# Out:
#    Depth  Temp
# 6   1100   215
# 7   1200   282
# 8   1400   223

# %% [markdown]
# Con estos datos haremos una interpolación cuadrática, por ejemplo en el punto $1350$.

# %%
# Obtenemos los datos del DataFrame
x0, f0 = datos.iloc[6,0], datos.iloc[6,1]
x1, f1 = datos.iloc[7,0], datos.iloc[7,1]
x2, f2 = datos.iloc[8,0], datos.iloc[8,1]

# Construimos el sistema lineal.
A = np.array([[1, x0, x0**2],
              [1, x1, x1**2],
              [1, x2, x2**2]])
RHS = np.array([f0,f1,f2])

# R4solvemos el sistema para obtener los coeficientes
sol = np.linalg.solve(A,RHS)
a, b, c = sol[0], sol[1], sol[2] # Renombramos los coef.

# Realizamos la interpolación
xj = 1350 # Punto para donde se hará la interpolación
yj = S_q(xj, a, b, c)
print(f"Resultado de la interpolación: {yj}")
# Out:
# Resultado de la interpolación: 261.875

# %% [markdown]
# ### Paso 3. Graficamos el resultado de la interpolación.

# %%
# Graficación de los datos 
plt.scatter(datos.Temp, datos.Depth, label='Datos',
            ec='dimgrey', fc='darkgrey', alpha=0.95, zorder=5, )
# Líneas que unen a los datos
plt.plot(datos.Temp, datos.Depth, 
         '--', color='darkgrey', lw = 1.0)

# Datos interpolados
plt.scatter(yj, xj, ec='brown', fc='tomato', s = 20, zorder=5, 
            label='Punto interpolado') 

# Gráfica de la función cuadrática
xq = np.linspace(1100,1400,50)
yq = S_q(xq, a, b, c)
plt.plot(yq, xq, lw = 0.75, c='k', label="Función cuadrática")

ax = plt.gca() # Obtenemos los ejes de la figura
ax.invert_yaxis() # Invertimos el eje y

# Ponemos los ticks y labels en arriba
ax.tick_params(axis='x', top=True, labeltop=True, bottom=False, labelbottom=False)

# Modificamos algunas líneas del marco.
ax.spines['top'].set_visible(True)
ax.spines['bottom'].set_visible(False)

plt.title('Temperatura [$^o$C]', loc="center", y=1.10)
plt.ylabel('Profundidad [km]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **¿Qué opinas de esta interpolación**

# %% [markdown]
# <div class="alert alert-success">
#
# ## Ejemplo 3.
#
# Aplicar la interpolación **cuadrática** a los datos de *Canet et al. (2015)* para conocer la temperatura en 100 puntos de profundidad igualmente espaciados desde $0$ a $4000$ metros.
#
# </div>

# %% [markdown]
# ### Paso 1. Interpolaciones en cada intervalo.
#
# Para realizar este ejemplo podemos interpolar **cuadráticamente** entre cada par de datos. Para ello es conveniente construir una función que genere todas las funciones cuadráticas entre cada para puntos. Esta función se muestra en la siguiente celda.
#
# <div class="alert alert-info">
#
# **NOTA**. El algoritmo que se implementa en esta función es un poco más complejo que en el caso lineal. Las matemáticas de este algoritmo se muestran al final de esta notebook.
#
# </div>

# %%
def cuadratica(x, f, z):
    """
    Parameters:
    x: Arreglo de datos
    f: Arreglo de datos correspondientes con el arreglo x
    Z: Arreglo de datos donde se desea interpolar.

    Returns.
    y: Puntos interpolados.
    """

    k = len(x)-1  # Número de intervalos 
    N = 3*k       # Tamaño del sistema lineal
    # Matriz de tamaño N = 3*k para almacenar los coeficientes del sistema de ecuaciones
    A = np.zeros((N, N))
    
    # Condición de igualdad en puntos internos
    for i in range(k):
        A[2*i    , 3*i]     = 1         # a_i
        A[2*i    , 3*i + 1] = x[i]      # b_i
        A[2*i    , 3*i + 2] = x[i]**2   # c_i
        A[2*i + 1, 3*i]     = 1         # a_i+1
        A[2*i + 1, 3*i + 1] = x[i+1]    # b_i+1
        A[2*i + 1, 3*i + 2] = x[i+1]**2 # c_i+1
    
    # Condición de continuidad de las derivadas en puntos internos
    for i in range(k - 1):
        A[2*k + i, 3*i + 1] =  1            # b_i
        A[2*k + i, 3*i + 2] =  2 * x[i + 1] # c_i
        A[2*k + i, 3*i + 4] = -1            # b_i+1
        A[2*k + i, 3*i + 5] = -2 * x[i + 1] # c_i+1        
    A[3*k - 1, 2] = 2 # c_0 (Segunda derivada)

    # Lado derecho del sistema
    RHS = np.zeros(N)
    # Asignamos los valores de f(x)
    RHS[0] = f[0]
    for i in range(1, 2*k - 1, 2):
        RHS[i] = f[(i + 1)//2]
        RHS[i + 1] = f[(i + 1)//2]
    RHS[2*k - 1] = f[k]
    
    # Resolvemos el sistema 
    sol = np.linalg.solve(A, RHS)
    
    # Renombramos los coeficientes para un mejor entendimiento
    a = sol[::3]
    b = sol[1::3]
    c = sol[2::3]

    # Arreglo para almacenar la interpolación
    y = np.zeros_like(z)

    # Recorremos todos los datos z
    for j, xj in enumerate(z):
        # Por cada intervalo se hace la interpolación cuadrática
        for i in range(k):
            if xj >= x[i] and xj <= x[i + 1]:
                # Calculo de la interpolación cuadrática
                y[j] = S_q(xj, a[i], b[i], c[i])
                break
                
    return y # Regresamos las interpolaciones

# %% [markdown]
# ### Paso 2. Generar las profundidades requeridas.
#
# Generamos los datos de profundidades donde se requiere hacer la interpolación para obtener la temperatura.

# %%
L = max(datos.Depth)        # Profundidad máxima
N = 99                      # Número de incógnitas (usamos 99 por conveniencia)
z = np.linspace(0, L, N+2)  # Coordenada z de la profundidad

print(len(z))
print(z)
# Out:
# 101
# [   0.   40.   80.  120.  160.  200.  240.  280.  320.  360.  400.  440.
#   480.  520.  560.  600.  640.  680.  720.  760.  800.  840.  880.  920.
#   960. 1000. 1040. 1080. 1120. 1160. 1200. 1240. 1280. 1320. 1360. 1400.
#  1440. 1480. 1520. 1560. 1600. 1640. 1680. 1720. 1760. 1800. 1840. 1880.
#  1920. 1960. 2000. 2040. 2080. 2120. 2160. 2200. 2240. 2280. 2320. 2360.
#  2400. 2440. 2480. 2520. 2560. 2600. 2640. 2680. 2720. 2760. 2800. 2840.
#  2880. 2920. 2960. 3000. 3040. 3080. 3120. 3160. 3200. 3240. 3280. 3320.
#  3360. 3400. 3440. 3480. 3520. 3560. 3600. 3640. 3680. 3720. 3760. 3800.
#  3840. 3880. 3920. 3960. 4000.]

# %% [markdown]
# ### Paso 3. Realizar la interpolación.

# %%
yint= cuadratica(datos.Depth, datos.Temp, z) # Interpolación cuadrática

# %% [markdown]
# El arreglo `yint` contiene los datos de las temperaturas interpoladas.

# %%
print(yint)
# Out:
# [  15.           54.2          93.4         129.96        148.04
#   145.          135.44        133.96        140.56        155.24
#   178.          200.95900104  216.23600416  223.83100937  223.74401665
#   215.97502601  200.52403746  177.39105099  148.22796855  149.37663314
#   195.70416233  259.76759258  305.0431258   331.35034806  338.68925934
#   327.05985967  296.46214902  246.89612742  190.26626697  197.99940046
#   282.          377.34746606  419.12119909  407.32119909  341.94746606
#   223.          136.03940046  166.62626697  286.29373303  324.24059954
#   252.          180.71940046  221.54626697  346.21373303  385.12059954
#   310.          205.89253394  157.83880091  165.83880091  229.89253394
#   350.          486.92358597  601.42567872  693.50627827  763.1653846
#   810.40299772  835.21911763  837.61374432  817.58687781  775.13851808
#   710.26866515  622.977319    513.26447964  386.73552036  277.022681
#   189.73133485  124.86148192   82.41312219   62.38625568   64.78088237
#    89.59700228  136.8346154   206.49372173  298.57432128  413.07641403
#   550.          686.92358597  801.42567872  893.50627827  963.1653846
#  1010.40299772 1035.21911763 1037.61374432 1017.58687781  975.13851808
#   910.26866515  822.977319    713.26447964  586.73552036  477.022681
#   389.73133485  324.86148192  282.41312219  262.38625568  264.78088237
#   289.59700228  336.8346154   406.49372173  498.57432128  613.07641403
#   750.        ]

# %%
# Graficación de los datos 
plt.scatter(datos.Temp, datos.Depth, label='Datos',
            ec='dimgrey', fc='darkgrey', alpha=0.95, zorder=5, )
# Líneas que unen a los datos
plt.plot(datos.Temp, datos.Depth, 
         '--', color='darkgrey', lw = 1.0)

# Datos interpolados
plt.scatter(yint, z, ec='brown', fc='tomato', s = 10, zorder=3, 
            label='Puntos interpolados') 

# Gráfica de la función cuadrática
xq = np.linspace(0,4000,1000)
yq = cuadratica(datos.Depth, datos.Temp, xq) 
plt.plot(yq, xq, lw = 0.75, c='k')

ax = plt.gca() # Obtenemos los ejes de la figura
ax.invert_yaxis() # Invertimos el eje y

# Ponemos los ticks y labels en arriba
ax.tick_params(axis='x', top=True, labeltop=True, bottom=False, labelbottom=False)

# Modificamos algunas líneas del marco.
ax.spines['top'].set_visible(True)
ax.spines['bottom'].set_visible(False)

plt.title('Temperatura [$^o$C]', loc="center", y=1.10)
plt.ylabel('Profundidad [km]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Con base en este resultado:
#
# * ¿Qué opinas de esta interpolación?
# * ¿Es correcta numéricamente?
# * ¿Reproduce la realidad?
# * ¿La usarías en algún proyecto? ¿Por qué?
# * ¿Cómo podrías mejorar esta interpolación?

# %% [markdown]
# # Algoritmo de interpolación cuadrática.
#
# Consideramos el conjunto de datos $[(x_0, f(x_0), \dots (x_k, f(x_k)]$. Esto genera $k$ intervalos, en cada uno de los cuales se va a construir una curva cuadrática. La forma matemática de estas curvas, para el intervalo $i$ es la siguiente:
#
# $$
# S_i(x) = a_i + b_i x + c_i x^2 \;\;\; \text{para} \;\;\; x \in [x_{i}, x_{i+1}] \;\;\; \text{con} \;\;\; i = 0, k-1
# $$
#
# En total se tienen $k$ ecuaciones, lo que nos da un total de $3*k$ coeficientes por calcular. Además se deben cumplir las siguientes condiciones:
#
# 1. **Continuidad**: las curvas $S_i$ deben pasar por los puntos $(x_i, f_i)$ y $(x_{i+1}, f_{i+1})$, donde $f_i = f(x_i)$ y $f_{i+1} = f(x_{i+1}$. Esta condición implica:
#
# $$
# \begin{eqnarray}
# S_i(x_i) & = & a_i + b_i x_i + c_i x_i^2 = f_i \\
# S_i(x_{i+1}) & = & a_i + b_i x_{i+1} + c_i x_{i+1}^2 = f_{i+1}
# \end{eqnarray}
# $$
#
# Para $i = 0, k-1$ esto nos proporciona $2k$ ecuaciones.
#
# 2. **Suavidad**: las derivadas de las $S_i(x)$ en los puntos intermedios deben ser iguales. Esto implica:
#
# $$
# S_i^{\prime}(x_{i+1}) = S_{i+1}^{\prime}(x_{i+1})
# $$
#
# Para $i = 0, k-2$ esto nos proporciona $k-1$ ecuaciones.
#
# 3. La segunda derivada de $S_0$ en el punto inicial se hace igual a cero.
#
# $$
# S_0^{\prime\prime}(x) = 2 c_0 = 0
# $$
#
# Por lo tanto, en total se tienen $2k + (k-1) + 1 = 3k$ ecuaciones.
#
# Con estas ecuaciones, podemos formar un sistema lineal como el siguiente:
#
# $$
# \underbrace{
# \left[
# \begin{array}{cccccccccccccc}
# 1 & x_0 & x_0^2 & 0 & 0 & 0 & 0 & 0 & 0 & 0 &\dots \\
# 1 & x_1 & x_1^2 & 0 & 0 & 0 & 0 & 0 & 0 & 0 &\dots \\
# 0 & 0 & 0 & 1 & x_1 & x_1^2 & 0 & 0 & 0 & 0 &\dots \\
# 0 & 0 & 0 & 1 & x_2 & x_2^2 & 0 & 0 & 0 & 0 &\dots \\
# 0 & 0 & 0 & 0 & 0 & 0 & 1 & x_2 & x_2^2 & 0 &\dots \\
# 0 & 0 & 0 & 0 & 0 & 0 & 1 & x_3 & x_3^2 & 0 &\dots \\
# \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots\\
# 0 & 1 & 2x_1 & 0 & -1 & -2x_1 & 0 & 0 & 0 & 0 & \dots \\
# 0 & 0 & 0 & 0 & 1 & 2x_2 & 0 & -1 & -2x_2 & 0 & \dots \\
# \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots\\
# 2 & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 & \dots
# \end{array}
# \right]}_{A}
# \underbrace{
# \left[
# \begin{array}{c}
# a_0 \\ b_0 \\ c_0 \\ a_1 \\ b_1 \\ c_1  \\ a_2 \\ \vdots \\ c_{k-2} \\ a_{k-1} \\ b_{k-1} \\ c_{k-1}
# \end{array}
# \right]}_{sol} =
# \underbrace{
# \left[
# \begin{array}{c}
# f_0 \\ f_1 \\ f_1 \\ f_2 \\ f_2 \\ f_3 \\ f_3 \\ \vdots \\ f_k \\ 0 \\ \vdots \\ 0
# \end{array}
# \right]}_{RHS}
# $$
#
# La función `cuadratica(x, f, z)` mostrada antes, construye este sistema lineal, lo resuelve para encontrar los coeficientes $a_i$, $b_i$ y $c_i$ y realiza la interpolación.
