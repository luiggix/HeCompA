# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as wd

# %%
def graf(t, y):
    plt.plot(t, y)
    plt.show()

# %%
def solver(w):
    t = np.linspace(0, 2* np.pi, 100)
    y = np.sin(w * t)
    graf(t,y)

# %%
w = 4
solver(w)

# %%
wd.interact(solver, w = wd.FloatSlider(min=0.0, max=10.0, step=1.0, value=-1.0, description='x0'))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='x0', max=10.0, step=1.0), Output()), _dom_classes=('…
# <function __main__.solver(w)>
